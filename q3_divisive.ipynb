# %%
from google.colab import drive
drive.mount('/content/drive')
# !pwd
# Out:
# Mounted at /content/drive
# /content

# %%
# !ls
# %cd drive/MyDrive/DA/clustering
# !pwd
# Out:
# drive  sample_data
# /content/drive/.shortcut-targets-by-id/16BzENDslJoHpb3XlZqeoy64RYYEZ8ltp/clustering
# /content/drive/.shortcut-targets-by-id/16BzENDslJoHpb3XlZqeoy64RYYEZ8ltp/clustering

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from math import pi
from sklearn.manifold import TSNE
from sklearn.cluster import AgglomerativeClustering
from sklearn import preprocessing
from sklearn import metrics
from sklearn.metrics import silhouette_score
import scipy.cluster.hierarchy as shc
from sklearn.preprocessing import StandardScaler, normalize, MinMaxScaler
import collections
from queue import Queue
from sklearn.cluster import KMeans

# %% [markdown]
# ##Loading Pre-processed Data (Columns with very high correlation are removed)

# %%
df_data_pro_names = pd.read_csv('dropped_football_data_with_names.csv', na_values=np.NaN)
print(df_data_pro_names.shape)
display(df_data_pro_names.head())
display(df_data_pro_names.info())
display(df_data_pro_names.describe())
# Out:
# (18147, 50)
#                 Name  Age  ...  Attack Work Rate  Defense Work Rate
# 0           L. Messi   31  ...                 1                  1
# 1  Cristiano Ronaldo   33  ...                 2                  0
# 2          Neymar Jr   26  ...                 2                  1
# 3             De Gea   27  ...                 1                  1
# 4       K. De Bruyne   27  ...                 2                  2
#
# [5 rows x 50 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18147 entries, 0 to 18146
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      18147 non-null  object
#  1   Age                       18147 non-null  int64
#  2   Overall                   18147 non-null  int64
#  3   Potential                 18147 non-null  int64
#  4   Value                     18147 non-null  float64
#  5   Wage                      18147 non-null  float64
#  6   Special                   18147 non-null  int64
#  7   Preferred Foot            18147 non-null  int64
#  8   International Reputation  18147 non-null  float64
#  9   Weak Foot                 18147 non-null  float64
#  10  Skill Moves               18147 non-null  float64
#  11  Body Type                 18147 non-null  int64
#  12  Real Face                 18147 non-null  int64
#  13  Jersey Number             18147 non-null  float64
#  14  Height                    18147 non-null  float64
#  15  Weight                    18147 non-null  int64
#  16  LS                        18147 non-null  float64
#  17  LWB                       18147 non-null  float64
#  18  Crossing                  18147 non-null  float64
#  19  Finishing                 18147 non-null  float64
#  20  HeadingAccuracy           18147 non-null  float64
#  21  ShortPassing              18147 non-null  float64
#  22  Volleys                   18147 non-null  float64
#  23  Dribbling                 18147 non-null  float64
#  24  Curve                     18147 non-null  float64
#  25  FKAccuracy                18147 non-null  float64
#  26  LongPassing               18147 non-null  float64
#  27  BallControl               18147 non-null  float64
#  28  Acceleration              18147 non-null  float64
#  29  SprintSpeed               18147 non-null  float64
#  30  Agility                   18147 non-null  float64
#  31  Reactions                 18147 non-null  float64
#  32  Balance                   18147 non-null  float64
#  33  ShotPower                 18147 non-null  float64
#  34  Jumping                   18147 non-null  float64
#  35  Stamina                   18147 non-null  float64
#  36  Strength                  18147 non-null  float64
#  37  LongShots                 18147 non-null  float64
#  38  Aggression                18147 non-null  float64
#  39  Interceptions             18147 non-null  float64
#  40  Positioning               18147 non-null  float64
#  41  Vision                    18147 non-null  float64
#  42  Penalties                 18147 non-null  float64
#  43  Composure                 18147 non-null  float64
#  44  Marking                   18147 non-null  float64
#  45  StandingTackle            18147 non-null  float64
#  46  GKDiving                  18147 non-null  float64
#  47  Release Clause            18147 non-null  float64
#  48  Attack Work Rate          18147 non-null  int64
#  49  Defense Work Rate         18147 non-null  int64
# dtypes: float64(39), int64(10), object(1)
# memory usage: 6.9+ MB
# None
#                 Age       Overall  ...  Attack Work Rate  Defense Work Rate
# count  18147.000000  18147.000000  ...      18147.000000       18147.000000
# mean      25.121122     66.253926  ...          1.218218           1.086185
# std        4.669796      6.913320  ...          0.521755           0.502896
# min       16.000000     46.000000  ...          0.000000           0.000000
# 25%       21.000000     62.000000  ...          1.000000           1.000000
# 50%       25.000000     66.000000  ...          1.000000           1.000000
# 75%       28.000000     71.000000  ...          2.000000           1.000000
# max       45.000000     94.000000  ...          2.000000           2.000000
#
# [8 rows x 49 columns]

# %%
df_data_pro = df_data_pro_names.drop(['Name'],axis=1)

# %% [markdown]
# ##Standardizing Data

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_data_pro.values)
X_df = pd.DataFrame(X_scaled)

# %% [markdown]
# ##Class for Divisive Clustering

# %%
class Divisive(object):
    def __init__(self, k, X):
        self.X = X.copy()
        self.n_rows, self.n_features = X.shape
        self.dendo_labels = np.array([2*(self.n_rows-1) for i in range(self.n_rows)])
        self.clustr_labels = []
        self.K = k
        self.children_info = np.zeros((self.n_rows-1,2))  ## stores internal_node : child0_cluster_label, child1_cluster_label

    def fit(self):
        ## tree leaves = no. of samples/rows
        ## tree non-leaf nodes = tree_leaves-1 = num_samples-1
        ## total labels = non_leaf_nodes-1 = num_samples-2
        Q = Queue(maxsize=self.n_rows)
        latest_label = self.n_rows-3
        Q.put(latest_label+1)
        clusters_formed = 1

        while Q.empty() is False:
            cur_parent = Q.get()
            cur_node = cur_parent + self.n_rows
            cur_idxs = np.where(self.dendo_labels==cur_node)[0]
            cur_cluster = self.X[self.dendo_labels==cur_node]
            km = KMeans(n_clusters=2, random_state=1).fit(cur_cluster)
            clusters_formed += 1
            sub_cluster0 = np.where(km.labels_==0)[0]
            sub_cluster1 = np.where(km.labels_==1)[0]

            if sub_cluster0.shape[0]==1:
                this_label = cur_idxs[sub_cluster0[0]]
                self.children_info[cur_parent][0] = this_label
                self.dendo_labels[this_label] = this_label
            else:
                Q.put(latest_label)
                this_label = latest_label + self.n_rows
                self.dendo_labels[[cur_idxs[i] for i in sub_cluster0]] = this_label
                self.children_info[cur_parent][0] = this_label
                latest_label -= 1
            # print("c0",this_label, self.children_info[cur_parent][0])
            if sub_cluster1.shape[0]==1:
                this_label = cur_idxs[sub_cluster1[0]]
                self.children_info[cur_parent][1] = this_label
                self.dendo_labels[this_label] = this_label
            else:
                Q.put(latest_label)
                this_label = latest_label + self.n_rows
                self.dendo_labels[[cur_idxs[i] for i in sub_cluster1]] = this_label
                self.children_info[cur_parent][1] = this_label
                latest_label -= 1
            # print("c1",this_label, self.children_info[cur_parent][1])
            if clusters_formed == self.K:
                self.clustr_labels = self.dendo_labels.copy()
                unq_labels = np.unique(self.clustr_labels)
                cid = 0
                for c in unq_labels:
                    mask = np.where(self.clustr_labels==c)[0]
                    self.clustr_labels[mask] = cid
                    cid += 1 

        return self.clustr_labels, self.children_info

# %% [markdown]
# ##Functions for Analysing Clusters
# 1) Quality of clusters : Silhoutte score  (cluster centroids calculated using cluster means)
# 2) Detecting outliers : Datapoints having negative silhoutte score
# 3) Intracluster distance : Average Complete Diameter
# 4) Intercluster distance : Average Linkage Distance
# 5) Similar attributes per cluster : Top K attributes having the minimum average difference
# 6) Attributes different in outliers : Top K attributes having the maximum average difference
# 7) Most discriminative feature between pair of clusters : Max distances between attribute-wise mean (centroids) of the clusters

# %%
def euclid_distance(X1, X2):
    all_dists = -2 * np.dot(X1, X2.T) + np.sum(X2**2, axis=1) + np.sum(X1**2, axis=1)[:, np.newaxis]
    return all_dists

def euclid_vectors(X1, X2):
    all_dists = -2 * np.dot(X1, X2.T) + X2**2 + (X1**2)[:, np.newaxis]
    return all_dists

def silhouette_score(labels,data):
    centroids = []
    clusters = {}
    unq_labels = np.unique(labels)
    for cl in unq_labels:
        clusters[cl] = data[labels==cl,:]
        centroids.append(np.mean(clusters[cl],axis=0))
    centroids = np.array(centroids)
    center_dists = euclid_distance(centroids,centroids)
    tot_S = []
    outliers = []
    for c in range(len(unq_labels)):
        cur_cdists = euclid_distance(clusters[c],clusters[c])
        a = np.sum(cur_cdists,axis=1) / (len(clusters[c])-1)
        nearest_center = np.argmin(np.concatenate((center_dists[c,:c],center_dists[c,c+1:])))
        nearest_cdists = euclid_distance(clusters[c],clusters[nearest_center])
        b = np.sum(nearest_cdists,axis=1) / (len(clusters[nearest_center]))
        s = None
        if len(clusters[nearest_center]) > 1:
            s = (b - a) / np.max(np.stack((a,b),axis=0),axis=0)
        else:
            s = np.array([0])
        outliers.extend(clusters[c][s<0])
        tot_S.append(s.mean())
    return np.mean(tot_S), np.array(outliers)

def avg_diameter_dist(labels,data):
    diam = 0
    unq_labels = np.unique(labels)
    for cl in unq_labels:
        if cl==-1:
            continue
        cluster = data[labels==cl,:]
        cur_cdists = euclid_distance(cluster,cluster)
        # print("Points in cluster",cl," : ",cur_cdists.shape[0])
        ad = np.mean(cur_cdists)
        diam += ad
    print("\nAverage Complete Diameter (Intracluster) :",diam//len(unq_labels))

def avg_linkage_dist(labels,data):
    linkage = 0
    unq_labels = np.unique(labels)
    # print(unq_labels)
    for i in range(len(unq_labels)):
        if unq_labels[i]==-1:
            continue
        c1 = data[labels==unq_labels[i],:]
        j = i+1
        while j < len(unq_labels):
            if unq_labels[j]==-1:
                j+=1
                continue
            c2 = data[labels==unq_labels[j],:]
            cur_cdists = euclid_distance(c1,c2)
            ad = np.mean(cur_cdists)
            # print(i,j,ad)
            linkage += ad
            j += 1
        i += 1
    print("\nAverage Linkage Distance (Intercluster) :",linkage//len(unq_labels))

def cluster_diff_by(labels,data,cols,k=1):
    clst_means = []
    all_dists = []
    unq_labels = np.unique(labels)
    for cl in unq_labels:
        if cl==-1:
            continue
        clst_means.append(np.mean(data[labels==cl],axis=0))
    clst_means = np.array(clst_means)
    for i in range(len(clst_means)):
        cur_dist = (clst_means - clst_means[i])**2
        for j in range(i+1,len(cur_dist)):
            indx = np.argmax(cur_dist[j])
            print("\nMost discriminative feature in clusters",i,"&",j,": ",cols[indx])


def similar_attributes(labels,data,cols,k=5):
    std = StandardScaler()
    # data_std = std.fit_transform(data)  ## bring all features to same scale
    for cl in np.unique(labels):
        if cl==-1:
            continue
        mean_dists = []
        cluster = data[labels==cl,:]
        for col in range(len(cols)):
            cur_cdists = euclid_vectors(cluster[:,col],cluster[:,col])
            # print(cur_cdists.shape)
            ad = abs(np.mean(cur_cdists))
            mean_dists.append(ad)
        mean_dists = np.asarray(mean_dists)
        indx = np.argsort(mean_dists)[:k]
        print("\nTop K similar features in cluster ",cl," : ",list(cols[indx]))
        print("Name of cluster",cl," : ",tuple(cols[indx])[:3])
        

def diff_attrs_outliers(labels,data,cols,k=5):
    # std = StandardScaler()
    # data = std.fit_transform(data)  ## bring all features to same scale
    outliers = data[labels==-1,:]
    mean_dists = []
    for col in range(len(cols)):
        cur_cdists = euclid_vectors(outliers[:,col],outliers[:,col])
        # print(cur_cdists.shape)
        ad = abs(np.mean(cur_cdists))
        mean_dists.append(ad)
    mean_dists = np.asarray(mean_dists)
    indx = np.argsort(mean_dists)[:k]
    print("\nTop K different features in outliers : ",list(cols[indx]))

# %% [markdown]
# ##Divisive Clustering with 3 Clusters

# %%
diana = Divisive(3,X_scaled)
labels, children = diana.fit()
counts = collections.Counter(labels)
print(counts)

score, outliers = silhouette_score(labels,X_scaled)
print("\nSilhouette Score:",score,"\nNumber of outliers:",len(outliers))
avg_diameter_dist(labels,X_scaled)
avg_linkage_dist(labels,X_scaled)
similar_attributes(labels,X_scaled,df_data_pro.columns)
cluster_diff_by(labels,X_scaled,df_data_pro.columns)
diff_attrs_outliers(labels,X_scaled,df_data_pro.columns)
# Out:
# Counter({1: 8796, 0: 7200, 2: 2151})
#
# Silhouette Score: 0.3225592761197133
# Number of outliers: 7319
#
# Average Complete Diameter (Intracluster) : 56.0
#
# Average Linkage Distance (Intercluster) : 162.0
#
# Top K similar features in cluster  0  :  ['GKDiving', 'LWB', 'LS', 'HeadingAccuracy', 'Release Clause']
# Name of cluster 0  :  ('GKDiving', 'LWB', 'LS')
#
# Top K similar features in cluster  1  :  ['LS', 'Wage', 'GKDiving', 'International Reputation', 'LWB']
# Name of cluster 1  :  ('LS', 'Wage', 'GKDiving')
#
# Top K similar features in cluster  2  :  ['Defense Work Rate', 'Attack Work Rate', 'Wage', 'Preferred Foot', 'Value']
# Name of cluster 2  :  ('Defense Work Rate', 'Attack Work Rate', 'Wage')
#
# Most discriminative feature in clusters 0 & 1 :  Overall
#
# Most discriminative feature in clusters 0 & 2 :  LS
#
# Most discriminative feature in clusters 1 & 2 :  GKDiving
#
# Top K different features in outliers :  ['Age', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility']
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plt.figure(figsize =(10, 10))
plt.title('Visualising the data')
Dendrogram = shc.dendrogram((shc.linkage(children, method ='ward')))

# %% [markdown]
# ##Divisive Clustering with 5 Clusters

# %%
diana = Divisive(5,X_scaled)
labels, children = diana.fit()
counts = collections.Counter(labels)
print(counts)

score, outliers = silhouette_score(labels,X_scaled)
print("\nSilhouette Score:",score,"\nNumber of outliers:",len(outliers))
avg_diameter_dist(labels,X_scaled)
avg_linkage_dist(labels,X_scaled)
similar_attributes(labels,X_scaled,df_data_pro.columns)
cluster_diff_by(labels,X_scaled,df_data_pro.columns)
diff_attrs_outliers(labels,X_scaled,df_data_pro.columns)
# Out:
# Counter({4: 7200, 0: 4601, 1: 4195, 3: 1112, 2: 1039})
#
# Silhouette Score: 0.13342389220103923
# Number of outliers: 7350
#
# Average Complete Diameter (Intracluster) : 48.0
#
# Average Linkage Distance (Intercluster) : 280.0
#
# Top K similar features in cluster  0  :  ['International Reputation', 'LS', 'Wage', 'LWB', 'GKDiving']
# Name of cluster 0  :  ('International Reputation', 'LS', 'Wage')
#
# Top K similar features in cluster  1  :  ['LS', 'GKDiving', 'Wage', 'LWB', 'International Reputation']
# Name of cluster 1  :  ('LS', 'GKDiving', 'Wage')
#
# Top K similar features in cluster  2  :  ['Defense Work Rate', 'Attack Work Rate', 'Strength', 'Preferred Foot', 'Jumping']
# Name of cluster 2  :  ('Defense Work Rate', 'Attack Work Rate', 'Strength')
#
# Top K similar features in cluster  3  :  ['International Reputation', 'Defense Work Rate', 'Wage', 'Real Face', 'Attack Work Rate']
# Name of cluster 3  :  ('International Reputation', 'Defense Work Rate', 'Wage')
#
# Top K similar features in cluster  4  :  ['GKDiving', 'LWB', 'LS', 'HeadingAccuracy', 'Release Clause']
# Name of cluster 4  :  ('GKDiving', 'LWB', 'LS')
#
# Most discriminative feature in clusters 0 & 1 :  Strength
#
# Most discriminative feature in clusters 0 & 2 :  GKDiving
#
# Most discriminative feature in clusters 0 & 3 :  LS
#
# Most discriminative feature in clusters 0 & 4 :  Overall
#
# Most discriminative feature in clusters 1 & 2 :  GKDiving
#
# Most discriminative feature in clusters 1 & 3 :  LWB
#
# Most discriminative feature in clusters 1 & 4 :  Vision
#
# Most discriminative feature in clusters 2 & 3 :  Reactions
#
# Most discriminative feature in clusters 2 & 4 :  GKDiving
#
# Most discriminative feature in clusters 3 & 4 :  Special
#
# Top K different features in outliers :  ['Age', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility']
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ##Divisive Clustering with 7 Clusters

# %%
diana = Divisive(7,X_scaled)
labels, children = diana.fit()
counts = collections.Counter(labels)
print(counts)

score, outliers = silhouette_score(labels,X_scaled)
print("\nSilhouette Score:",score,"\nNumber of outliers:",len(outliers))
avg_diameter_dist(labels,X_scaled)
avg_linkage_dist(labels,X_scaled)
similar_attributes(labels,X_scaled,df_data_pro.columns)
cluster_diff_by(labels,X_scaled,df_data_pro.columns)
diff_attrs_outliers(labels,X_scaled,df_data_pro.columns)
# Out:
# Counter({3: 5745, 4: 4601, 5: 4195, 2: 1455, 6: 1039, 1: 987, 0: 125})
#
# Silhouette Score: 0.2614641726237717
# Number of outliers: 12178
#
# Average Complete Diameter (Intracluster) : 46.0
#
# Average Linkage Distance (Intercluster) : 437.0
#
# Top K similar features in cluster  0  :  ['International Reputation', 'Real Face', 'LWB', 'GKDiving', 'Wage']
# Name of cluster 0  :  ('International Reputation', 'Real Face', 'LWB')
#
# Top K similar features in cluster  1  :  ['Defense Work Rate', 'International Reputation', 'Wage', 'Attack Work Rate', 'Real Face']
# Name of cluster 1  :  ('Defense Work Rate', 'International Reputation', 'Wage')
#
# Top K similar features in cluster  2  :  ['GKDiving', 'Release Clause', 'Jersey Number', 'Value', 'SprintSpeed']
# Name of cluster 2  :  ('GKDiving', 'Release Clause', 'Jersey Number')
#
# Top K similar features in cluster  3  :  ['GKDiving', 'Wage', 'International Reputation', 'LWB', 'LS']
# Name of cluster 3  :  ('GKDiving', 'Wage', 'International Reputation')
#
# Top K similar features in cluster  4  :  ['International Reputation', 'LS', 'Wage', 'LWB', 'GKDiving']
# Name of cluster 4  :  ('International Reputation', 'LS', 'Wage')
#
# Top K similar features in cluster  5  :  ['LS', 'GKDiving', 'Wage', 'LWB', 'International Reputation']
# Name of cluster 5  :  ('LS', 'GKDiving', 'Wage')
#
# Top K similar features in cluster  6  :  ['Defense Work Rate', 'Attack Work Rate', 'Strength', 'Preferred Foot', 'Jumping']
# Name of cluster 6  :  ('Defense Work Rate', 'Attack Work Rate', 'Strength')
#
# Most discriminative feature in clusters 0 & 1 :  GKDiving
#
# Most discriminative feature in clusters 0 & 2 :  Overall
#
# Most discriminative feature in clusters 0 & 3 :  Vision
#
# Most discriminative feature in clusters 0 & 4 :  Dribbling
#
# Most discriminative feature in clusters 0 & 5 :  ShortPassing
#
# Most discriminative feature in clusters 0 & 6 :  GKDiving
#
# Most discriminative feature in clusters 1 & 2 :  Special
#
# Most discriminative feature in clusters 1 & 3 :  LS
#
# Most discriminative feature in clusters 1 & 4 :  GKDiving
#
# Most discriminative feature in clusters 1 & 5 :  LWB
#
# Most discriminative feature in clusters 1 & 6 :  Reactions
#
# Most discriminative feature in clusters 2 & 3 :  International Reputation
#
# Most discriminative feature in clusters 2 & 4 :  International Reputation
#
# Most discriminative feature in clusters 2 & 5 :  International Reputation
#
# Most discriminative feature in clusters 2 & 6 :  LS
#
# Most discriminative feature in clusters 3 & 4 :  Overall
#
# Most discriminative feature in clusters 3 & 5 :  Vision
#
# Most discriminative feature in clusters 3 & 6 :  GKDiving
#
# Most discriminative feature in clusters 4 & 5 :  Strength
#
# Most discriminative feature in clusters 4 & 6 :  GKDiving
#
# Most discriminative feature in clusters 5 & 6 :  GKDiving
#
# Top K different features in outliers :  ['Age', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility']
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
